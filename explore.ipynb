# %% [markdown]
# # Data Profiling — First Look
#
# Run each cell in order with **Shift+Enter**. Look at the output before moving on.
#
# > **Your job**: spot as many data quality issues as you can before starting Exercise 4A.
# > Discuss with your partner. Then compare your list with the 8 issues in `exercises/exercise_4a/README.md`.

# %%
import pandas as pd

df = pd.read_csv('data/transactions_messy.csv')
print(f'Loaded {len(df)} rows × {len(df.columns)} columns')

# %%
# First 10 rows — what do the raw values look like?
df.head(10)

# %%
# Column types — are they what you'd expect for a transactions dataset?
df.dtypes

# %%
# Missing values per column
df.isnull().sum()

# %%
# Descriptive statistics — pay attention to min/max/mean for amount
df.describe(include='all')

# %%
# Unique values in category — do they look consistent?
df['category'].value_counts()

# %%
# Sample of the branch column — anything hidden in the values?
df['branch'].unique()

# %%
# Sample of customer_id — do all values follow the same format?
df['customer_id'].sample(20, random_state=1).tolist()

# %% [markdown]
# ## What did you notice?
#
# Double-click this cell and fill in your list, or click **+ Markdown** to add a new cell below.
#
# - Issue 1:
# - Issue 2:
# - Issue 3:
# - Issue 4:
#
# ---
#
# > When you're done, open `exercises/exercise_4a/README.md` and check your list against the 8 known issues.
# > Then open `exercises/exercise_4a/starter.py` to begin.
